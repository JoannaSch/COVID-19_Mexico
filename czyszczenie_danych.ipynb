# %%
import pandas as pd

# %%
df = pd.read_csv("Covid Data.csv")
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %%
df['died'] = df['DATE_DIED']
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['died'] == '9999-99-99', 'died'] = 0
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['died'] != 0, 'died'] = 1
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df['died'] = df['died'].astype('int64')

# %%
df.dtypes
# Out:
# USMER                    int64
# MEDICAL_UNIT             int64
# SEX                      int64
# PATIENT_TYPE             int64
# DATE_DIED               object
# INTUBED                  int64
# PNEUMONIA                int64
# AGE                      int64
# PREGNANT                 int64
# DIABETES                 int64
# COPD                     int64
# ASTHMA                   int64
# INMSUPR                  int64
# HIPERTENSION             int64
# OTHER_DISEASE            int64
# CARDIOVASCULAR           int64
# OBESITY                  int64
# RENAL_CHRONIC            int64
# TOBACCO                  int64
# CLASIFFICATION_FINAL     int64
# ICU                      int64
# died                     int64
# dtype: object

# %%
df.loc[df['CLASIFFICATION_FINAL'] >= 4, 'CLASIFFICATION_FINAL'] = 0
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['CLASIFFICATION_FINAL'] > 0, 'CLASIFFICATION_FINAL'] = 1
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['PATIENT_TYPE'] == 1, 'PATIENT_TYPE'] = 0
df.loc[df['PATIENT_TYPE'] == 2, 'PATIENT_TYPE'] = 1
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             0  03/05/2020       97
# 1            2             1    2             0  03/06/2020       97
# 2            2             1    2             1  09/06/2020        1
# 3            2             1    1             0  12/06/2020       97
# 4            2             1    2             0  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             0  9999-99-99       97
# 1048571      1            13    2             1  9999-99-99        2
# 1048572      2            13    2             0  9999-99-99       97
# 1048573      2            13    2             0  9999-99-99       97
# 1048574      2            13    2             0  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['INTUBED'] == 2, 'INTUBED'] = 0
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             0  03/05/2020       97
# 1            2             1    2             0  03/06/2020       97
# 2            2             1    2             1  09/06/2020        1
# 3            2             1    1             0  12/06/2020       97
# 4            2             1    2             0  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             0  9999-99-99       97
# 1048571      1            13    2             1  9999-99-99        0
# 1048572      2            13    2             0  9999-99-99       97
# 1048573      2            13    2             0  9999-99-99       97
# 1048574      2            13    2             0  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['PNEUMONIA'] == 1, 'PNEUMONIA'] = 1
df.loc[df['PNEUMONIA'] == 2, 'PNEUMONIA'] = 0
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             0  03/05/2020       97
# 1            2             1    2             0  03/06/2020       97
# 2            2             1    2             1  09/06/2020        1
# 3            2             1    1             0  12/06/2020       97
# 4            2             1    2             0  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             0  9999-99-99       97
# 1048571      1            13    2             1  9999-99-99        0
# 1048572      2            13    2             0  9999-99-99       97
# 1048573      2            13    2             0  9999-99-99       97
# 1048574      2            13    2             0  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['PREGNANT'] == 1, 'PREGNANT'] = 1
df.loc[df['PREGNANT'] == 2, 'PREGNANT'] = 0
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             0  03/05/2020       97
# 1            2             1    2             0  03/06/2020       97
# 2            2             1    2             1  09/06/2020        1
# 3            2             1    1             0  12/06/2020       97
# 4            2             1    2             0  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             0  9999-99-99       97
# 1048571      1            13    2             1  9999-99-99        0
# 1048572      2            13    2             0  9999-99-99       97
# 1048573      2            13    2             0  9999-99-99       97
# 1048574      2            13    2             0  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['DIABETES'] == 1, 'DIABETES'] = 1
df.loc[df['DIABETES'] == 2, 'DIABETES'] = 0
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             0  03/05/2020       97
# 1            2             1    2             0  03/06/2020       97
# 2            2             1    2             1  09/06/2020        1
# 3            2             1    1             0  12/06/2020       97
# 4            2             1    2             0  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             0  9999-99-99       97
# 1048571      1            13    2             1  9999-99-99        0
# 1048572      2            13    2             0  9999-99-99       97
# 1048573      2            13    2             0  9999-99-99       97
# 1048574      2            13    2             0  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['COPD'] == 1, 'COPD'] = 1
df.loc[df['COPD'] == 2, 'COPD'] = 0
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             0  03/05/2020       97
# 1            2             1    2             0  03/06/2020       97
# 2            2             1    2             1  09/06/2020        1
# 3            2             1    1             0  12/06/2020       97
# 4            2             1    2             0  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             0  9999-99-99       97
# 1048571      1            13    2             1  9999-99-99        0
# 1048572      2            13    2             0  9999-99-99       97
# 1048573      2            13    2             0  9999-99-99       97
# 1048574      2            13    2             0  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
df.loc[df['ASTHMA'] == 1, 'ASTHMA'] = 1
df.loc[df['ASTHMA'] == 2, 'ASTHMA'] = 0
df
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             0  03/05/2020       97
# 1            2             1    2             0  03/06/2020       97
# 2            2             1    2             1  09/06/2020        1
# 3            2             1    1             0  12/06/2020       97
# 4            2             1    2             0  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             0  9999-99-99       97
# 1048571      1            13    2             1  9999-99-99        0
# 1048572      2            13    2             0  9999-99-99       97
# 1048573      2            13    2             0  9999-99-99       97
# 1048574      2            13    2             0  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  INMSUPR  HIPERTENSION  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(17,17))
sns.heatmap(data=df.corr(), annot=True, fmt=".2f");

# %%
df.isna().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# died                    0
# dtype: int64
